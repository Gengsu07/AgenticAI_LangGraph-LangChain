# %%
from dotenv import load_dotenv
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import CSVLoader
from langchain_community.document_loaders import WebBaseLoader
from pprint import pprint
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# ### PDF

# %%
pdfloader = PyMuPDFLoader("katalog-produk-unggulan.pdf")
katalogpdf = pdfloader.load()

# %%
pprint(katalogpdf[5])
# Out:
# Document(metadata={'producer': 'iLovePDF', 'creator': 'Adobe InDesign 15.0 (Macintosh)', 'creationdate': '2024-07-31T03:17:36+07:00', 'source': 'katalog-produk-unggulan.pdf', 'file_path': 'katalog-produk-unggulan.pdf', 'total_pages': 32, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-27T20:37:15+00:00', 'trapped': '', 'modDate': 'D:20241027203715Z', 'creationDate': "D:20240731031736+07'00'", 'page': 5}, page_content='Al Barokah Herbal\nHealthy with Natural Ingredients\nManfaat : Membantu meringankan bengkak / memar akibat \nkeseleo / terkilir / terbentur dan dapat sebagai minyak gosok.\nNIE : TR226045721\nHerbal Oil Almahyra plus Bidara (100 ml)\nKATALOG Produk Unggulan UMKM \n3')

# %%
pprint(katalogpdf[5].page_content)
# Out:
# ('Al Barokah Herbal\n'
#  'Healthy with Natural Ingredients\n'
#  'Manfaat : Membantu meringankan bengkak / memar akibat \n'
#  'keseleo / terkilir / terbentur dan dapat sebagai minyak gosok.\n'
#  'NIE : TR226045721\n'
#  'Herbal Oil Almahyra plus Bidara (100 ml)\n'
#  'KATALOG Produk Unggulan UMKM \n'
#  '3')

# %% [markdown]
# ### TextLoader / Markdown

# %%
textloader = TextLoader("layanan.md")
layanandoc = textloader.load()
pprint(layanandoc)
# Out:
# [Document(metadata={'source': 'layanan.md'}, page_content='✨ PROMO KAWAT GIGI DISCOVERY Januari✨Semua kebutuhan behel dalam harga yang lebih hemat. 📍 GiO Cabang Jogja, Semarang, Denpasar, Magelang, dan Kuta- Potongan harga 4.900.000 jadi 4.250.000 - Sudah termasuk: Biaya konsultasi, cetak gigi, rontgen, scaling, dan ortho kit. 📅 Berlaku 7-31 Januari 2026 👉 (Klaim Promonya) \\***\\*\\_\\_\\*\\*** Apa Itu Kawat Gigi American Metal?Kawat gigi atau behel American Metal adalah alat ortodonti yang digunakan untuk merapikan dan memperbaiki posisi gigi yang tidak rata atau berjejal.Behel ini terbuat dari bahan stainless steel dan terdiri dari bracket yang direkatkan pada gigi serta dihubungkan dengan kawat lengkung (archwire) untuk menggeser gigi secara bertahap ke posisi yang seharusnya. Mengapa Behel American Metal Penting?Behel American Metal penting untuk membantu mengatasi masalah ortodonti seperti gigi berjejal, celah antar gigi, dan gangguan gigitan.Dengan pergeseran gigi secara perlahan, behel ini membantu meningkatkan fungsi pengunyahan dan menjaga kesehatan mulut secara keseluruhan. Keunggulan Behel American MetalTahan lama dan sangat efektifMemiliki kekuatan yang cukup untuk memberikan tekanan yang dibutuhkan agar gigi cepat berpindah ke posisi yang tepatRelatif lebih terjangkau dibandingkan jenis behel lainnya, sehingga menjadi pilihan populer untuk perawatan ortodonti Biaya Behel Gigi American MetalMau tau berapa harga pasang behel American Metal di GiO Dental Care?Tenang, harganya masih masuk akal kok, mulai dari Rp4 juta hingga Rp7,5 juta, tergantung dari kondisi gigimu.Karena setiap kasus beda-beda, sebaiknya kamu konsultasi dulu biar tahu pasti berapa biaya pasang behel yang paling sesuai.Yuk, bikin janji konsultasi sekarang dan mulai perjalanan menuju senyum rapi dan sehat! Dengan Behel American Metal, gigi yang tidak rata dapat diperbaiki secara efektif, membantu Anda mendapatkan senyum yang lebih sehat dan percaya diri.Untuk informasi lebih lengkap mengenai prosedur pemasangan, harga, serta konsultasi dengan dokter gigi kami di GiO Dental Care, hubungi MinCan sekarang!\n\n---\n\nKenapa Perlu GiO Ceramic Crown, Bridge, dan Implant?GiO Ceramic Crown, Bridge, dan Implant adalah solusi untuk menggantikan atau memperbaiki gigi yang rusak atau hilang, guna mengembalikan fungsi dan estetika senyum Anda.Perawatan ini mencakup pemasangan mahkota gigi keramik (ceramic crown), jembatan gigi (bridge), serta implant gigi.Mahkota dan jembatan gigi berbahan keramik berkualitas tinggi memberikan tampilan alami serta daya tahan yang optimal.Sementara itu, implant gigi berfungsi sebagai akar gigi tiruan permanen yang menyatu dengan tulang rahang, memberikan stabilitas maksimal dan hasil yang tahan lama.Dengan GiO Ceramic Crown, Bridge, dan Implant, Anda bisa mendapatkan solusi terbaik untuk senyum yang lebih sehat, kuat, dan percaya diri. Keunggulan GiO Ceramic Crown, Bridge, dan ImplantCeramic crown & bridge memberikan tampilan alami, menyerupai gigi asli.Implant gigi sebagai solusi permanen yang kuat dan tahan lama.Membantu memperbaiki fungsi mengunyah dan mencegah pergeseran gigi lainnya.Bahan keramik berkualitas tinggi yang aman dan biokompatibel.Prosedur dilakukan oleh dokter spesialis untuk hasil yang presisi dan nyaman.\n\n---\n\nVeneer gigi adalah lapisan tipis yang dibuat dari bahan porselen atau resin komposit yang dirancang untuk menutupi permukaan depan gigi.Veneer gigi memberikan penampilan yang lebih rapi dan putih. Tujuan dari veneer gigi adalah untuk memperbaiki estetika gigi, seperti warna, bentuk, atau ukuran.Temukan cabang klinik GiO Dental Care di kota Anda untuk melakukan layanan veneer gigi terdekat. 2 Jenis Veneer Gigi di GiO Dental Care🦷 Direct Veneer: Menggunakan bahan komposit dan dapat dilakukan dalam 1 kali kunjungan.Prosedurnya ialah dengan memberikan lapisan resin komposit pada gigi tanpa mengurangi gigi tersebut apabila gigi sehat dan tidak karies.Jadi gigi sayang GiO tetap aman dan sehat.🦷 Indirect Ve ...

# %% [markdown]
# ### CSV

# %%
csvloader = CSVLoader("produk.csv")
produkdoc = csvloader.load()
pprint(produkdoc)
# Out:
# [Document(metadata={'source': 'produk.csv', 'row': 0}, page_content='id: 1\nproduk: a\nharga: 100000'),
#  Document(metadata={'source': 'produk.csv', 'row': 1}, page_content='id: 2\nproduk: b\nharga: 200000'),
#  Document(metadata={'source': 'produk.csv', 'row': 2}, page_content='id: 3\nproduk: c\nharga: 300000'),
#  Document(metadata={'source': 'produk.csv', 'row': 3}, page_content='id: 4\nproduk: d\nharga: 400000'),
#  Document(metadata={'source': 'produk.csv', 'row': 4}, page_content='id: 5\nproduk: e\nharga: 500000')]
