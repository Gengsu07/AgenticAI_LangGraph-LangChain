# %%
from dotenv import load_dotenv
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import CSVLoader
from langchain_community.document_loaders import WebBaseLoader
from pprint import pprint
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# ### PDF

# %%
pdfloader = PyMuPDFLoader("katalog-produk-unggulan.pdf")
katalogpdf = pdfloader.load()

# %%
pprint(katalogpdf[5])
# Out:
# Document(metadata={'producer': 'iLovePDF', 'creator': 'Adobe InDesign 15.0 (Macintosh)', 'creationdate': '2024-07-31T03:17:36+07:00', 'source': 'katalog-produk-unggulan.pdf', 'file_path': 'katalog-produk-unggulan.pdf', 'total_pages': 32, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-27T20:37:15+00:00', 'trapped': '', 'modDate': 'D:20241027203715Z', 'creationDate': "D:20240731031736+07'00'", 'page': 5}, page_content='Al Barokah Herbal\nHealthy with Natural Ingredients\nManfaat : Membantu meringankan bengkak / memar akibat \nkeseleo / terkilir / terbentur dan dapat sebagai minyak gosok.\nNIE : TR226045721\nHerbal Oil Almahyra plus Bidara (100 ml)\nKATALOG Produk Unggulan UMKM \n3')

# %%
pprint(katalogpdf[5].metadata)
# Out:
# {'author': '',
#  'creationDate': "D:20240731031736+07'00'",
#  'creationdate': '2024-07-31T03:17:36+07:00',
#  'creator': 'Adobe InDesign 15.0 (Macintosh)',
#  'file_path': 'katalog-produk-unggulan.pdf',
#  'format': 'PDF 1.4',
#  'keywords': '',
#  'modDate': 'D:20241027203715Z',
#  'moddate': '2024-10-27T20:37:15+00:00',
#  'page': 5,
#  'producer': 'iLovePDF',
#  'source': 'katalog-produk-unggulan.pdf',
#  'subject': '',
#  'title': '',
#  'total_pages': 32,
#  'trapped': ''}

# %%
pprint(katalogpdf[5].page_content)
# Out:
# ('Al Barokah Herbal\n'
#  'Healthy with Natural Ingredients\n'
#  'Manfaat : Membantu meringankan bengkak / memar akibat \n'
#  'keseleo / terkilir / terbentur dan dapat sebagai minyak gosok.\n'
#  'NIE : TR226045721\n'
#  'Herbal Oil Almahyra plus Bidara (100 ml)\n'
#  'KATALOG Produk Unggulan UMKM \n'
#  '3')

# %% [markdown]
# ### TextLoader / Markdown

# %%
textloader = TextLoader("layanan.md", autodetect_encoding=True)
layanandoc = textloader.load()
pprint(layanandoc)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File d:\PROJECTS\AgenticAI_LangGraph-LangChain\.venv\Lib\site-packages\langchain_community\document_loaders\text.py:43, in TextLoader.lazy_load(self)
#      42     with open(self.file_path, encoding=self.encoding) as f:
# ---> 43         text = f.read()
#      44 except UnicodeDecodeError as e:
#
# File C:\ProgramData\miniconda3\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 96: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
# ...

# %% [markdown]
# ### CSV

# %%
csvloader = CSVLoader("produk.csv")
produkdoc = csvloader.load()
pprint(produkdoc)
# Out:
# [Document(metadata={'source': 'produk.csv', 'row': 0}, page_content='id: 1\nproduk: a\nharga: 100000'),
#  Document(metadata={'source': 'produk.csv', 'row': 1}, page_content='id: 2\nproduk: b\nharga: 200000'),
#  Document(metadata={'source': 'produk.csv', 'row': 2}, page_content='id: 3\nproduk: c\nharga: 300000'),
#  Document(metadata={'source': 'produk.csv', 'row': 3}, page_content='id: 4\nproduk: d\nharga: 400000'),
#  Document(metadata={'source': 'produk.csv', 'row': 4}, page_content='id: 5\nproduk: e\nharga: 500000')]
