# %%
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv
import os

# %%
load_dotenv()
openai_key = os.getenv("OPENAI_API_KEY")
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")
os.environ["LANGSMITH_TRACING"] = os.getenv("LANGSMITH_TRACING")
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
openai = ChatOpenAI(name="simplechat", model="gpt-5-nano", openai_api_key=openai_key)

# %%
gemini = ChatGoogleGenerativeAI(model="gemini-flash-latest")

# %%
openai
# Out:
# ChatOpenAI(name='simplechat', profile={'max_input_tokens': 272000, 'max_output_tokens': 128000, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x1252fdd00>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x1242b8470>, root_client=<openai.OpenAI object at 0x1250ac200>, root_async_client=<openai.AsyncOpenAI object at 0x1250acb30>, model_name='gpt-5-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
gemini
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-flash-latest', client=<google.genai.client.Client object at 0x124461250>, default_metadata=(), model_kwargs={})

# %%
result = openai.invoke(
    "how to get money 5000 dollars a month as mother with 1 kid from indonesia, what digital skills  need to learn and get flexible job?"
)

# %%
result_gemini = gemini.invoke(
    "istri saya ingin bekerja dari rumah untuk mendapatkan gaji dollar 5000 per bulan, dengan 1 anak. Apa saja keterampilan digital yang harus dia pelajari agar bisa mendapatkan pekerjaan fleksibel? apa peluang terbaik saat ini"
)

# %%
print(result.content)
# Out:
# Short answer: yes, it’s possible to earn money remotely from Indonesia while caring for a child, but reaching USD 5,000/month usually requires a combination of skills, steady freelance work or remote roles, and often more than one income stream. It’s easier if you target higher-paying roles or multiple retainer-style clients. Here’s a practical path you can start now.
#
# What digital skills to learn (high-potential for flexible remote work)
# - Web development (best if you like tech)
#   - Frontend: HTML, CSS, JavaScript, React or Vue
#   - Optional: basic backend (Node.js or Python), APIs
#   - Why: lots of remote freelance work; average freelance rates can be $25–$60+/hour depending on skill and portfolio
# - Graphic design / UI design
#   - Tools: Figma (or Sketch), Canva, basic Photoshop/Illustrator
#   - Why: design work for websites, social media, marketing assets; decent demand; easy to show in a portfolio
# - Copywriting and content creation
# ...

# %%
print(result_gemini.content)
# Out:
# Ini adalah tujuan yang sangat ambisius dan realistis jika dipersiapkan dengan strategi yang tepat.
#
# Gaji **$5.000 USD per bulan** ($60.000 USD per tahun) adalah gaji tingkat senior atau spesialis yang sangat dicari di pasar global (Amerika Utara atau Eropa). Untuk mencapai angka ini, istri Anda tidak bisa hanya menawarkan keterampilan administrasi umum; dia harus menawarkan **keterampilan digital yang berdampak langsung pada pendapatan atau efisiensi bisnis klien**.
#
# Berikut adalah panduan lengkap mengenai keterampilan digital yang harus dipelajari, peluang terbaik saat ini, dan strategi untuk mencapai tujuan tersebut sambil mengurus anak.
#
# ---
#
# ## 1. Realitas Gaji $5.000 USD Per Bulan
#
# Untuk mencapai target $5.000 USD per bulan, istri Anda harus bersaing di pasar global. Ini berarti:
#
# ...
